# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd /content/drive/MyDrive/kaggle/UWMGI/

# シンボリックリンクを作成
# !ln -sfn /content/drive/MyDrive/kaggle/UWMGI/ /content/workspace

# !apt-get install vim
# kaggle api
# !pip install kaggle

# current directory 変更
import os
# path を通す
import sys
sys.path.append("../")

# import したもの自動reloadする設定
# %load_ext autoreload
# %autoreload 2

os.environ["KAGGLE_CONFIG_DIR"] = "/content/workspace"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/kaggle/UWMGI
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libgpm2 vim-common vim-runtime xxd
# Suggested packages:
#   gpm ctags vim-doc vim-scripts
# The following NEW packages will be installed:
#   libgpm2 vim vim-common vim-runtime xxd
# 0 upgraded, 5 newly installed, 0 to remove and 49 not upgraded.
# Need to get 6,725 kB of archives.
# After this operation, 32.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xxd amd64 2:8.0.1453-1ubuntu1.8 [49.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim-common all 2:8.0.1453-1ubuntu1.8 [71.1 kB]
# ...

# %%
# hdf5 dataset 2022/06/20
#!kaggle datasets init -p './data/upload'
#!kaggle datasets create -p './data/upload/'
# Out:
# Starting upload for file dataset.hdf5
# 100% 12.3G/12.3G [03:03<00:00, 71.8MB/s]
# Upload successful: dataset.hdf5 (12GB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/hdf5dataset

# %%
# nb004 2022/06/20
#!kaggle datasets init -p './model/nb004'
#!kaggle datasets create -p './model/nb004'
# Out:
# Starting upload for file dataset.hdf5
# 100% 12.3G/12.3G [02:00<00:00, 109MB/s]
# Upload successful: dataset.hdf5 (12GB)
# Dataset creation error: The requested title "UWMGI_hdf5dataset" is already in use by a dataset. Please choose another title.

# %%
# nb008 2022/06/20
#!kaggle datasets init -p './model/nb008/'
#!kaggle datasets create -p './model/nb008'
# Out:
# Starting upload for file nb008-0-best.bin
# 100% 24.2M/24.2M [00:05<00:00, 4.93MB/s]
# Upload successful: nb008-0-best.bin (24MB)
# Starting upload for file nb008-1-best.bin
# 100% 24.2M/24.2M [00:03<00:00, 6.37MB/s]
# Upload successful: nb008-1-best.bin (24MB)
# Starting upload for file nb008-2-best.bin
# 100% 24.2M/24.2M [00:03<00:00, 6.92MB/s]
# Upload successful: nb008-2-best.bin (24MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb008

# %%
# nb009 2022/06/21
#!kaggle datasets init -p './model/nb009/'
# !kaggle datasets create -p './model/nb009'
# Out:
# Starting upload for file nb009-0-best.bin
# 100% 24.2M/24.2M [00:00<00:00, 25.5MB/s]
# Upload successful: nb009-0-best.bin (24MB)
# Starting upload for file nb009-1-best.bin
# 100% 24.2M/24.2M [00:00<00:00, 28.2MB/s]
# Upload successful: nb009-1-best.bin (24MB)
# Starting upload for file nb009-2-best.bin
# 100% 24.2M/24.2M [00:02<00:00, 10.3MB/s]
# Upload successful: nb009-2-best.bin (24MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb009

# %%
# nb010 2022/06/21
#!kaggle datasets init -p './model/nb010/'
#!kaggle datasets create -p './model/nb010'
# Out:
# Starting upload for file nb010-0-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 22.1MB/s]
# Upload successful: nb010-0-best.bin (24MB)
# Starting upload for file nb010-1-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 18.1MB/s]
# Upload successful: nb010-1-best.bin (24MB)
# Starting upload for file nb010-2-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 18.4MB/s]
# Upload successful: nb010-2-best.bin (24MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb010

# %%
# nb011 2022/06/21
#!kaggle datasets init -p './model/nb011/'
#!kaggle datasets create -p './model/nb011'
# Out:
# Starting upload for file nb011-0-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 23.3MB/s]
# Upload successful: nb011-0-best.bin (24MB)
# Starting upload for file nb011-1-best.bin
# 100% 24.2M/24.2M [00:00<00:00, 25.9MB/s]
# Upload successful: nb011-1-best.bin (24MB)
# Starting upload for file nb011-2-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 24.6MB/s]
# Upload successful: nb011-2-best.bin (24MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb011

# %%
# nb012 2022/06/22
#!kaggle datasets init -p './model/nb012/'
# !kaggle datasets create -p './model/nb012'
# Out:
# Starting upload for file nb012-0-best.bin
# 100% 24.2M/24.2M [00:03<00:00, 7.20MB/s]
# Upload successful: nb012-0-best.bin (24MB)
# Starting upload for file nb012-1-best.bin
# 100% 24.2M/24.2M [00:03<00:00, 8.03MB/s]
# Upload successful: nb012-1-best.bin (24MB)
# Starting upload for file nb012-2-best.bin
# 100% 24.2M/24.2M [00:02<00:00, 9.25MB/s]
# Upload successful: nb012-2-best.bin (24MB)
# Starting upload for file nb012-3-best.bin
# 100% 24.2M/24.2M [00:04<00:00, 6.23MB/s]
# Upload successful: nb012-3-best.bin (24MB)
# Starting upload for file nb012-4-best.bin
# 100% 24.2M/24.2M [00:03<00:00, 7.61MB/s]
# Upload successful: nb012-4-best.bin (24MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb012

# %%
# nb014 2022/06/23
#!kaggle datasets init -p './model/nb014/'
# !kaggle datasets create -p './model/nb014'
# Out:
# Starting upload for file nb014-0-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 19.9MB/s]
# Upload successful: nb014-0-best.bin (24MB)
# Starting upload for file nb014-1-best.bin
# 100% 24.2M/24.2M [00:00<00:00, 25.8MB/s]
# Upload successful: nb014-1-best.bin (24MB)
# Starting upload for file nb014-2-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 16.9MB/s]
# Upload successful: nb014-2-best.bin (24MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb014

# %%
# nb015 2022/06/23
#!kaggle datasets init -p './model/nb015/'
# !kaggle datasets create -p './model/nb015'
# Out:
# Starting upload for file nb015-0-best.bin
# 100% 24.2M/24.2M [00:02<00:00, 10.4MB/s]
# Upload successful: nb015-0-best.bin (24MB)
# Starting upload for file nb015-1-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 14.3MB/s]
# Upload successful: nb015-1-best.bin (24MB)
# Starting upload for file nb015-2-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 14.4MB/s]
# Upload successful: nb015-2-best.bin (24MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb015

# %%
# nb015 2022/06/24
#!kaggle datasets init -p './model/nb016/'
#!kaggle datasets create -p './model/nb016'
# Out:
# Starting upload for file nb016-0-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 23.0MB/s]
# Upload successful: nb016-0-best.bin (24MB)
# Starting upload for file nb016-1-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 20.4MB/s]
# Upload successful: nb016-1-best.bin (24MB)
# Starting upload for file nb016-2-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 23.4MB/s]
# Upload successful: nb016-2-best.bin (24MB)
# Starting upload for file log_history.pkl
# 100% 935k/935k [00:00<00:00, 1.42MB/s]
# Upload successful: log_history.pkl (935KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb016

# %%
# nb018 2022/06/25
#!kaggle datasets init -p './model/nb018/'
#!kaggle datasets create -p './model/nb018'
# Out:
# Starting upload for file nb018-0-best.bin
# 100% 77.9M/77.9M [00:09<00:00, 8.89MB/s]
# Upload successful: nb018-0-best.bin (78MB)
# Starting upload for file log_history.pkl
# 100% 311k/311k [00:03<00:00, 89.5kB/s]
# Upload successful: log_history.pkl (311KB)
# Starting upload for file nb018-1-best.bin
# 100% 77.9M/77.9M [00:07<00:00, 10.3MB/s]
# Upload successful: nb018-1-best.bin (78MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb018

# %%
# nb018 2022/06/25
#!kaggle datasets init -p './model/nb017/'
# !kaggle datasets create -p './model/nb017'
# Out:
# Starting upload for file nb017-0-best.bin
# 100% 24.2M/24.2M [00:05<00:00, 4.65MB/s]
# Upload successful: nb017-0-best.bin (24MB)
# Starting upload for file nb017-1-best.bin
# 100% 24.2M/24.2M [00:04<00:00, 5.74MB/s]
# Upload successful: nb017-1-best.bin (24MB)
# Starting upload for file nb017-2-best.bin
# 100% 24.2M/24.2M [00:04<00:00, 5.34MB/s]
# Upload successful: nb017-2-best.bin (24MB)
# Starting upload for file log_history.pkl
# 100% 943k/943k [00:04<00:00, 225kB/s]
# Upload successful: log_history.pkl (943KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb017

# %%
# nb018 2022/06/26
#!kaggle datasets init -p './model/nb023/'
# !kaggle datasets create -p './model/nb023'
# Out:
# Starting upload for file nb023-0-best.bin
# 100% 24.2M/24.2M [00:02<00:00, 11.9MB/s]
# Upload successful: nb023-0-best.bin (24MB)
# Starting upload for file nb023-1-best.bin
# 100% 24.2M/24.2M [00:02<00:00, 12.5MB/s]
# Upload successful: nb023-1-best.bin (24MB)
# Starting upload for file nb023-2-best.bin
# 100% 24.2M/24.2M [00:00<00:00, 26.5MB/s]
# Upload successful: nb023-2-best.bin (24MB)
# Starting upload for file log_history.pkl
# 100% 945k/945k [00:00<00:00, 2.05MB/s]
# Upload successful: log_history.pkl (945KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb023

# %%
# nb018 2022/06/28
#!kaggle datasets init -p './model/nb025/'
#!kaggle datasets create -p './model/nb025'
# Out:
# Starting upload for file nb025-0-best.bin
# 100% 24.2M/24.2M [00:04<00:00, 6.11MB/s]
# Upload successful: nb025-0-best.bin (24MB)
# Starting upload for file nb025-1-best.bin
# 100% 24.2M/24.2M [00:03<00:00, 6.72MB/s]
# Upload successful: nb025-1-best.bin (24MB)
# Starting upload for file nb025-2-best.bin
# 100% 24.2M/24.2M [00:03<00:00, 6.39MB/s]
# Upload successful: nb025-2-best.bin (24MB)
# Starting upload for file log_history.pkl
# 100% 939k/939k [00:02<00:00, 407kB/s]
# Upload successful: log_history.pkl (939KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb025

# %%
# nb026 2022/06/29
#!kaggle datasets init -p './model/nb026/'
# !kaggle datasets create -p './model/nb026'
# Out:
# Starting upload for file nb026-0-best.bin
# 100% 24.2M/24.2M [00:01<00:00, 17.1MB/s]
# Upload successful: nb026-0-best.bin (24MB)
# Starting upload for file nb026-1-best.bin
# 100% 24.2M/24.2M [00:02<00:00, 9.93MB/s]
# Upload successful: nb026-1-best.bin (24MB)
# Starting upload for file nb026-2-best.bin
# 100% 24.2M/24.2M [00:02<00:00, 10.8MB/s]
# Upload successful: nb026-2-best.bin (24MB)
# Starting upload for file log_history.pkl
# 100% 218k/218k [00:00<00:00, 252kB/s]
# Upload successful: log_history.pkl (218KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb026

# %%
# nb027 2022/06/29
#!kaggle datasets init -p './model/nb027/'
# !kaggle datasets create -p './model/nb027'
# Out:
# Starting upload for file nb027-0-best.bin
# 100% 50.8M/50.8M [00:01<00:00, 32.3MB/s]
# Upload successful: nb027-0-best.bin (51MB)
# Starting upload for file nb027-1-best.bin
# 100% 50.8M/50.8M [00:01<00:00, 30.4MB/s]
# Upload successful: nb027-1-best.bin (51MB)
# Starting upload for file nb027-2-best.bin
# 100% 50.8M/50.8M [00:01<00:00, 33.9MB/s]
# Upload successful: nb027-2-best.bin (51MB)
# Starting upload for file log_history.pkl
# 100% 315k/315k [00:00<00:00, 471kB/s]
# Upload successful: log_history.pkl (315KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb027

# %%
# nb028 2022/06/30
#!kaggle datasets init -p './model/nb028/'
# !kaggle datasets create -p './model/nb028'
# Out:
# Starting upload for file nb028-0-best.bin
# 100% 77.9M/77.9M [00:09<00:00, 8.79MB/s]
# Upload successful: nb028-0-best.bin (78MB)
# Starting upload for file nb028-1-best.bin
# 100% 77.9M/77.9M [00:10<00:00, 8.05MB/s]
# Upload successful: nb028-1-best.bin (78MB)
# Starting upload for file nb028-2-best.bin
# 100% 77.9M/77.9M [00:12<00:00, 6.37MB/s]
# Upload successful: nb028-2-best.bin (78MB)
# Starting upload for file log_history.pkl
# 100% 317k/317k [00:03<00:00, 83.7kB/s]
# Upload successful: log_history.pkl (317KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb028

# %%
# nb0 2022/06/30
#!kaggle datasets init -p './model/nb030/'
#!kaggle datasets create -p './model/nb030'
# Out:
# Starting upload for file nb030-0-best.bin
# 100% 50.8M/50.8M [00:09<00:00, 5.37MB/s]
# Upload successful: nb030-0-best.bin (51MB)
# Starting upload for file nb030-1-best.bin
# 100% 50.8M/50.8M [00:08<00:00, 6.17MB/s]
# Upload successful: nb030-1-best.bin (51MB)
# Starting upload for file nb030-2-best.bin
# 100% 50.8M/50.8M [00:08<00:00, 6.21MB/s]
# Upload successful: nb030-2-best.bin (51MB)
# Starting upload for file log_history.pkl
# 100% 314k/314k [00:03<00:00, 101kB/s]
# Upload successful: log_history.pkl (314KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb030

# %%
# nb0 2022/07/03
#!kaggle datasets init -p './model/nb031/'
#!kaggle datasets create -p './model/nb031'
# Out:
# Starting upload for file nb031-0-best.bin
# 100% 77.9M/77.9M [00:08<00:00, 9.87MB/s]
# Upload successful: nb031-0-best.bin (78MB)
# Starting upload for file nb031-1-best.bin
# 100% 77.9M/77.9M [00:07<00:00, 11.0MB/s]
# Upload successful: nb031-1-best.bin (78MB)
# Starting upload for file nb031-2-best.bin
# 100% 77.9M/77.9M [00:07<00:00, 11.2MB/s]
# Upload successful: nb031-2-best.bin (78MB)
# Starting upload for file log_history.pkl
# 100% 214k/214k [00:02<00:00, 75.0kB/s]
# Upload successful: log_history.pkl (214KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb031

# %%
# nb0 2022/07/05
#!kaggle datasets init -p './model/nb032/'
# !kaggle datasets create -p './model/nb032'
# Out:
# Starting upload for file nb032-0-best.bin
# 100% 77.9M/77.9M [00:03<00:00, 20.6MB/s]
# Upload successful: nb032-0-best.bin (78MB)
# Starting upload for file nb032-1-best.bin
# 100% 77.9M/77.9M [00:04<00:00, 17.5MB/s]
# Upload successful: nb032-1-best.bin (78MB)
# Starting upload for file nb032-2-best.bin
# 100% 77.9M/77.9M [00:04<00:00, 18.9MB/s]
# Upload successful: nb032-2-best.bin (78MB)
# Starting upload for file log_history.pkl
# 100% 118k/118k [00:02<00:00, 45.5kB/s]
# Upload successful: log_history.pkl (118KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb032-2

# %%
# nb033 2022/07/07
#!kaggle datasets init -p './model/nb033/'
# !kaggle datasets create -p './model/nb033'
# Out:
# Starting upload for file nb033-0-best.bin
# 100% 77.9M/77.9M [00:09<00:00, 8.64MB/s]
# Upload successful: nb033-0-best.bin (78MB)
# Starting upload for file nb033-1-best.bin
# 100% 77.9M/77.9M [00:09<00:00, 8.41MB/s]
# Upload successful: nb033-1-best.bin (78MB)
# Starting upload for file nb033-2-best.bin
# 100% 77.9M/77.9M [00:09<00:00, 8.47MB/s]
# Upload successful: nb033-2-best.bin (78MB)
# Starting upload for file log_history.pkl
# 100% 122k/122k [00:04<00:00, 25.0kB/s]
# Upload successful: log_history.pkl (122KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb033

# %%
# nb033 2022/07/09
#!kaggle datasets init -p './model/nb035/'
# !kaggle datasets create -p './model/nb035'
# Out:
# Starting upload for file nb035-0-best.bin
# 100% 50.8M/50.8M [00:09<00:00, 5.60MB/s]
# Upload successful: nb035-0-best.bin (51MB)
# Starting upload for file nb035-1-best.bin
# 100% 50.8M/50.8M [00:08<00:00, 6.09MB/s]
# Upload successful: nb035-1-best.bin (51MB)
# Starting upload for file nb035-2-best.bin
# 100% 50.8M/50.8M [00:08<00:00, 6.35MB/s]
# Upload successful: nb035-2-best.bin (51MB)
# Starting upload for file log_history.pkl
# 100% 120k/120k [00:04<00:00, 26.7kB/s]
# Upload successful: log_history.pkl (120KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb035

# %%
# nb033 2022/07/09
#!kaggle datasets init -p './model/nb036/'
# !kaggle datasets create -p './model/nb036'
# Out:
# Starting upload for file nb036-0-best.bin
# 100% 77.9M/77.9M [00:02<00:00, 33.7MB/s]
# Upload successful: nb036-0-best.bin (78MB)
# Starting upload for file nb036-1-best.bin
# 100% 77.9M/77.9M [00:01<00:00, 42.1MB/s]
# Upload successful: nb036-1-best.bin (78MB)
# Starting upload for file nb036-2-best.bin
# 100% 77.9M/77.9M [00:03<00:00, 26.6MB/s]
# Upload successful: nb036-2-best.bin (78MB)
# Starting upload for file log_history.pkl
# 100% 103k/103k [00:00<00:00, 163kB/s]
# Upload successful: log_history.pkl (103KB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/yoshoo/UWMGI-nb036
